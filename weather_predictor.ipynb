# %%
import pandas as pd

weather = pd.read_csv("weather.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                        NAME  ACMH  \
# DATE
# 1970-01-01  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  30.0
# 1970-01-02  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US   0.0
# 1970-01-03  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  10.0
# 1970-01-04  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  30.0
# 1970-01-05  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  60.0
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US   NaN
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US   NaN
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US   NaN
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US   NaN
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US   NaN
#
#             ACSH  AWND  FMTM    PGTM  PRCP  SNOW  SNWD  ...  WT10  WT11  WT13  \
# DATE                                                    ...
# 1970-01-01  30.0   NaN   NaN  2330.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1970-01-02   0.0   NaN   NaN   324.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1970-01-03   0.0   NaN   NaN  2312.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1970-01-04  40.0   NaN   NaN  1030.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# 1970-01-05  80.0   NaN   NaN  1942.0  0.00   0.0   0.0  ...   NaN   NaN   NaN
# ...          ...   ...   ...     ...   ...   ...   ...  ...   ...   ...   ...
# 2025-11-20   NaN   NaN   NaN     NaN  0.23   NaN   NaN  ...   NaN   NaN   NaN
# 2025-11-21   NaN   NaN   NaN     NaN  0.00   NaN   NaN  ...   NaN   NaN   NaN
# 2025-11-22   NaN   NaN   NaN     NaN  0.00   NaN   NaN  ...   NaN   NaN   NaN
# 2025-11-23   NaN   NaN   NaN     NaN  0.00   NaN   NaN  ...   NaN   NaN   NaN
# 2025-11-24   NaN   NaN   NaN     NaN  0.00   NaN   NaN  ...   NaN   NaN   NaN
#
#             WT14  WT16  WT18  WT21  WV01  WV03  WV20
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1970-01-04   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...   ...   ...
# 2025-11-20   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2025-11-21   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2025-11-22   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2025-11-23   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2025-11-24   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [20417 rows x 41 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.522016
# ACSH       0.521771
# AWND       0.255424
# FMTM       0.501298
# PGTM       0.283489
# PRCP       0.000000
# SNOW       0.516971
# SNWD       0.519959
# TAVG       0.647157
# TMAX       0.000980
# TMIN       0.001029
# TSUN       0.940883
# WDF1       0.532302
# WDF2       0.479013
# WDF5       0.486898
# WDFG       0.529951
# WESD       0.713768
# WSF1       0.526767
# WSF2       0.479013
# WSF5       0.486898
# WSFG       0.524661
# WT01       0.699515
# WT02       0.980017
# WT03       0.990694
# WT04       0.998237
# WT05       0.989470
# WT07       0.996816
# WT08       0.782436
# WT09       0.999118
# WT10       0.999951
# WT11       0.999706
# WT13       0.923593
# WT14       0.963070
# WT16       0.784542
# WT18       0.999461
# WT21       0.996033
# WV01       0.997943
# WV03       0.999951
# WV20       0.999951
# dtype: float64

# %%
valid_columns = weather.columns[null_pct < 0.05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns = weather.columns.str.lower()

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-01  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-02  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-03  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-04  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-05  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin
# DATE
# 1970-01-01  59.0  39.0
# 1970-01-02  54.0  40.0
# 1970-01-03  52.0  35.0
# 1970-01-04  52.0  38.0
# 1970-01-05  50.0  34.0
# ...          ...   ...
# 2025-11-20  60.0  51.0
# 2025-11-21  64.0  47.0
# 2025-11-22  65.0  47.0
# 2025-11-23  58.0  47.0
# 2025-11-24  62.0  50.0
#
# [20417 rows x 5 columns]

# %%
weather = weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2025-11-15', '2025-11-16', '2025-11-17', '2025-11-18', '2025-11-19',
#        '2025-11-20', '2025-11-21', '2025-11-22', '2025-11-23', '2025-11-24'],
#       dtype='object', name='DATE', length=20417)

# %%
weather.index = pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2025-11-15', '2025-11-16', '2025-11-17', '2025-11-18',
#                '2025-11-19', '2025-11-20', '2025-11-21', '2025-11-22',
#                '2025-11-23', '2025-11-24'],
#               dtype='datetime64[ns]', name='DATE', length=20417, freq=None)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    366
# 2025    328
# Name: count, dtype: int64

# %%
weather["prcp"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-01  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-02  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-03  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-04  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-05  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin
# DATE
# 1970-01-01  59.0  39.0
# 1970-01-02  54.0  40.0
# 1970-01-03  52.0  35.0
# 1970-01-04  52.0  38.0
# 1970-01-05  50.0  34.0
# ...          ...   ...
# 2025-11-20  60.0  51.0
# 2025-11-21  64.0  47.0
# 2025-11-22  65.0  47.0
# 2025-11-23  58.0  47.0
# 2025-11-24  62.0  50.0
#
# [20417 rows x 5 columns]

# %%
weather["target"] = weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-01  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-02  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-03  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-04  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-05  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin  target
# DATE
# 1970-01-01  59.0  39.0    54.0
# 1970-01-02  54.0  40.0    52.0
# 1970-01-03  52.0  35.0    52.0
# 1970-01-04  52.0  38.0    50.0
# 1970-01-05  50.0  34.0    49.0
# ...          ...   ...     ...
# 2025-11-20  60.0  51.0    64.0
# 2025-11-21  64.0  47.0    65.0
# 2025-11-22  65.0  47.0    58.0
# 2025-11-23  58.0  47.0    62.0
# 2025-11-24  62.0  50.0     NaN
#
# [20417 rows x 6 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-01  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-02  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-03  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-04  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-05  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin  target
# DATE
# 1970-01-01  59.0  39.0    54.0
# 1970-01-02  54.0  40.0    52.0
# 1970-01-03  52.0  35.0    52.0
# 1970-01-04  52.0  38.0    50.0
# 1970-01-05  50.0  34.0    49.0
# ...          ...   ...     ...
# 2025-11-20  60.0  51.0    64.0
# 2025-11-21  64.0  47.0    65.0
# 2025-11-22  65.0  47.0    58.0
# 2025-11-23  58.0  47.0    62.0
# 2025-11-24  62.0  50.0    62.0
#
# [20417 rows x 6 columns]

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=0.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin'], dtype='object')

# %%
def backtest(weather, model, predictors, start=3650, step=90):
  all_predictions = []

  for i in range(start, weather.shape[0], step):
    train = weather.iloc[:i,:]
    test = weather.iloc[i:(i+step), :]

    model.fit(train[predictors], train["target"])

    preds = model.predict(test[predictors])

    preds = pd.Series(preds, index=test.index)

    combined = pd.concat([test["target"], preds], axis=1)

    combined.columns = ["actual", "prediction"]

    combined["diff"] = (combined["prediction"] - combined["actual"]).abs()

    all_predictions.append(combined)

  return pd.concat(all_predictions, axis=0)

# %%
predictions = backtest(weather, rr, predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    63.0   63.286326   0.286326
# 1979-12-31    57.0   64.518928   7.518928
# 1980-01-01    48.0   58.800236  10.800236
# 1980-01-02    55.0   52.256984   2.743016
# 1980-01-03    54.0   57.201984   3.201984
# ...            ...         ...        ...
# 2025-11-20    64.0   61.577408   2.422592
# 2025-11-21    65.0   63.906294   1.093706
# 2025-11-22    58.0   64.587353   6.587353
# 2025-11-23    62.0   59.819940   2.180060
# 2025-11-24    62.0   63.300195   1.300195
#
# [16767 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 3.547311495666337

# %%
def pct_diff(old, new):
  return (new - old) / old

def compute_rolling(weather, horizon, col):
  label = f"rolling_{horizon}_{col}"
  weather[label] = weather[col].rolling(horizon).mean()
  weather[f"pct_diff_{label}"] = pct_diff(weather[label], weather[col])
  return weather

rolling_horizons = [3,14]

for horizon in rolling_horizons:
  for col in ["tmax", "tmin", "prcp"]:
    weather = compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-01  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-02  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-03  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-04  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-05  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin  target  rolling_3_tmax  pct_diff_rolling_3_tmax  \
# DATE
# 1970-01-01  59.0  39.0    54.0             NaN                      NaN
# 1970-01-02  54.0  40.0    52.0             NaN                      NaN
# 1970-01-03  52.0  35.0    52.0       55.000000                -0.054545
# 1970-01-04  52.0  38.0    50.0       52.666667                -0.012658
# 1970-01-05  50.0  34.0    49.0       51.333333                -0.025974
# ...          ...   ...     ...             ...                      ...
# 2025-11-20  60.0  51.0    64.0       60.000000                 0.000000
# 2025-11-21  64.0  47.0    65.0       61.000000                 0.049180
# 2025-11-22  65.0  47.0    58.0       63.000000                 0.031746
# 2025-11-23  58.0  47.0    62.0       62.333333                -0.069519
# 2025-11-24  62.0  50.0    62.0       61.666667                 0.005405
#
#             rolling_3_tmin  pct_diff_rolling_3_tmin  rolling_3_prcp  \
# DATE
# 1970-01-01             NaN                      NaN             NaN
# 1970-01-02             NaN                      NaN             NaN
# 1970-01-03       38.000000                -0.078947        0.000000
# 1970-01-04       37.666667                 0.008850        0.000000
# 1970-01-05       35.666667                -0.046729        0.000000
# ...                    ...                      ...             ...
# 2025-11-20       51.333333                -0.006494        0.103333
# 2025-11-21       50.000000                -0.060000        0.076667
# 2025-11-22       48.333333                -0.027586        0.076667
# 2025-11-23       47.000000                 0.000000        0.000000
# 2025-11-24       48.000000                 0.041667        0.000000
#
#             pct_diff_rolling_3_prcp  rolling_14_tmax  \
# DATE
# 1970-01-01                      NaN              NaN
# 1970-01-02                      NaN              NaN
# 1970-01-03                      NaN              NaN
# 1970-01-04                      NaN              NaN
# 1970-01-05                      NaN              NaN
# ...                             ...              ...
# 2025-11-20                 1.225806        66.214286
# 2025-11-21                -1.000000        65.928571
# 2025-11-22                -1.000000        65.571429
# 2025-11-23                      NaN        64.142857
# 2025-11-24                      NaN        63.285714
#
#             pct_diff_rolling_14_tmax  rolling_14_tmin  \
# DATE
# 1970-01-01                       NaN              NaN
# 1970-01-02                       NaN              NaN
# 1970-01-03                       NaN              NaN
# 1970-01-04                       NaN              NaN
# 1970-01-05                       NaN              NaN
# ...                              ...              ...
# 2025-11-20                 -0.093851        54.785714
# 2025-11-21                 -0.029252        54.214286
# 2025-11-22                 -0.008715        53.714286
# 2025-11-23                 -0.095768        53.214286
# 2025-11-24                 -0.020316        52.714286
#
#             pct_diff_rolling_14_tmin  rolling_14_prcp  \
# DATE
# 1970-01-01                       NaN              NaN
# 1970-01-02                       NaN              NaN
# 1970-01-03                       NaN              NaN
# 1970-01-04                       NaN              NaN
# 1970-01-05                       NaN              NaN
# ...                              ...              ...
# 2025-11-20                 -0.069100         0.241429
# 2025-11-21                 -0.133070         0.241429
# 2025-11-22                 -0.125000         0.241429
# 2025-11-23                 -0.116779         0.241429
# 2025-11-24                 -0.051491         0.241429
#
#             pct_diff_rolling_14_prcp
# DATE
# 1970-01-01                       NaN
# 1970-01-02                       NaN
# 1970-01-03                       NaN
# 1970-01-04                       NaN
# 1970-01-05                       NaN
# ...                              ...
# 2025-11-20                 -0.047337
# 2025-11-21                 -1.000000
# 2025-11-22                 -1.000000
# 2025-11-23                 -1.000000
# 2025-11-24                 -1.000000
#
# [20417 rows x 18 columns]

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-15  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.53
# 1970-01-16  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.81
# 1970-01-17  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-18  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-19  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.03
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin  target  rolling_3_tmax  pct_diff_rolling_3_tmax  \
# DATE
# 1970-01-15  59.0  51.0    64.0       60.333333                -0.022099
# 1970-01-16  64.0  55.0    60.0       61.333333                 0.043478
# 1970-01-17  60.0  53.0    60.0       61.000000                -0.016393
# 1970-01-18  60.0  51.0    62.0       61.333333                -0.021739
# 1970-01-19  62.0  52.0    62.0       60.666667                 0.021978
# ...          ...   ...     ...             ...                      ...
# 2025-11-20  60.0  51.0    64.0       60.000000                 0.000000
# 2025-11-21  64.0  47.0    65.0       61.000000                 0.049180
# 2025-11-22  65.0  47.0    58.0       63.000000                 0.031746
# 2025-11-23  58.0  47.0    62.0       62.333333                -0.069519
# 2025-11-24  62.0  50.0    62.0       61.666667                 0.005405
#
#             rolling_3_tmin  pct_diff_rolling_3_tmin  rolling_3_prcp  \
# DATE
# 1970-01-15       52.333333                -0.025478        0.933333
# 1970-01-16       52.666667                 0.044304        1.143333
# 1970-01-17       53.000000                 0.000000        0.446667
# 1970-01-18       53.000000                -0.037736        0.270000
# 1970-01-19       52.000000                 0.000000        0.010000
# ...                    ...                      ...             ...
# 2025-11-20       51.333333                -0.006494        0.103333
# 2025-11-21       50.000000                -0.060000        0.076667
# 2025-11-22       48.333333                -0.027586        0.076667
# 2025-11-23       47.000000                 0.000000        0.000000
# 2025-11-24       48.000000                 0.041667        0.000000
#
#             pct_diff_rolling_3_prcp  rolling_14_tmax  \
# DATE
# 1970-01-15                -0.432143        55.571429
# 1970-01-16                -0.291545        56.285714
# 1970-01-17                -1.000000        56.857143
# 1970-01-18                -1.000000        57.428571
# 1970-01-19                 2.000000        58.285714
# ...                             ...              ...
# 2025-11-20                 1.225806        66.214286
# 2025-11-21                -1.000000        65.928571
# 2025-11-22                -1.000000        65.571429
# 2025-11-23                      NaN        64.142857
# 2025-11-24                      NaN        63.285714
#
#             pct_diff_rolling_14_tmax  rolling_14_tmin  \
# DATE
# 1970-01-15                  0.061697        44.785714
# 1970-01-16                  0.137056        45.857143
# 1970-01-17                  0.055276        47.142857
# 1970-01-18                  0.044776        48.071429
# 1970-01-19                  0.063725        49.357143
# ...                              ...              ...
# 2025-11-20                 -0.093851        54.785714
# 2025-11-21                 -0.029252        54.214286
# 2025-11-22                 -0.008715        53.714286
# 2025-11-23                 -0.095768        53.214286
# 2025-11-24                 -0.020316        52.714286
#
#             pct_diff_rolling_14_tmin  rolling_14_prcp  \
# DATE
# 1970-01-15                  0.138756         0.283571
# 1970-01-16                  0.199377         0.341429
# 1970-01-17                  0.124242         0.341429
# 1970-01-18                  0.060921         0.341429
# 1970-01-19                  0.053546         0.343571
# ...                              ...              ...
# 2025-11-20                 -0.069100         0.241429
# 2025-11-21                 -0.133070         0.241429
# 2025-11-22                 -0.125000         0.241429
# 2025-11-23                 -0.116779         0.241429
# 2025-11-24                 -0.051491         0.241429
#
#             pct_diff_rolling_14_prcp
# DATE
# 1970-01-15                  0.869018
# 1970-01-16                  1.372385
# 1970-01-17                 -1.000000
# 1970-01-18                 -1.000000
# 1970-01-19                 -0.912682
# ...                              ...
# 2025-11-20                 -0.047337
# 2025-11-21                 -1.000000
# 2025-11-22                 -1.000000
# 2025-11-23                 -1.000000
# 2025-11-24                 -1.000000
#
# [20403 rows x 18 columns]

# %%
weather = weather.fillna(0)

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-15  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.53
# 1970-01-16  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.81
# 1970-01-17  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-18  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-19  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.03
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin  target  rolling_3_tmax  pct_diff_rolling_3_tmax  \
# DATE
# 1970-01-15  59.0  51.0    64.0       60.333333                -0.022099
# 1970-01-16  64.0  55.0    60.0       61.333333                 0.043478
# 1970-01-17  60.0  53.0    60.0       61.000000                -0.016393
# 1970-01-18  60.0  51.0    62.0       61.333333                -0.021739
# 1970-01-19  62.0  52.0    62.0       60.666667                 0.021978
# ...          ...   ...     ...             ...                      ...
# 2025-11-20  60.0  51.0    64.0       60.000000                 0.000000
# 2025-11-21  64.0  47.0    65.0       61.000000                 0.049180
# 2025-11-22  65.0  47.0    58.0       63.000000                 0.031746
# 2025-11-23  58.0  47.0    62.0       62.333333                -0.069519
# 2025-11-24  62.0  50.0    62.0       61.666667                 0.005405
#
#             rolling_3_tmin  pct_diff_rolling_3_tmin  rolling_3_prcp  \
# DATE
# 1970-01-15       52.333333                -0.025478        0.933333
# 1970-01-16       52.666667                 0.044304        1.143333
# 1970-01-17       53.000000                 0.000000        0.446667
# 1970-01-18       53.000000                -0.037736        0.270000
# 1970-01-19       52.000000                 0.000000        0.010000
# ...                    ...                      ...             ...
# 2025-11-20       51.333333                -0.006494        0.103333
# 2025-11-21       50.000000                -0.060000        0.076667
# 2025-11-22       48.333333                -0.027586        0.076667
# 2025-11-23       47.000000                 0.000000        0.000000
# 2025-11-24       48.000000                 0.041667        0.000000
#
#             pct_diff_rolling_3_prcp  rolling_14_tmax  \
# DATE
# 1970-01-15                -0.432143        55.571429
# 1970-01-16                -0.291545        56.285714
# 1970-01-17                -1.000000        56.857143
# 1970-01-18                -1.000000        57.428571
# 1970-01-19                 2.000000        58.285714
# ...                             ...              ...
# 2025-11-20                 1.225806        66.214286
# 2025-11-21                -1.000000        65.928571
# 2025-11-22                -1.000000        65.571429
# 2025-11-23                 0.000000        64.142857
# 2025-11-24                 0.000000        63.285714
#
#             pct_diff_rolling_14_tmax  rolling_14_tmin  \
# DATE
# 1970-01-15                  0.061697        44.785714
# 1970-01-16                  0.137056        45.857143
# 1970-01-17                  0.055276        47.142857
# 1970-01-18                  0.044776        48.071429
# 1970-01-19                  0.063725        49.357143
# ...                              ...              ...
# 2025-11-20                 -0.093851        54.785714
# 2025-11-21                 -0.029252        54.214286
# 2025-11-22                 -0.008715        53.714286
# 2025-11-23                 -0.095768        53.214286
# 2025-11-24                 -0.020316        52.714286
#
#             pct_diff_rolling_14_tmin  rolling_14_prcp  \
# DATE
# 1970-01-15                  0.138756         0.283571
# 1970-01-16                  0.199377         0.341429
# 1970-01-17                  0.124242         0.341429
# 1970-01-18                  0.060921         0.341429
# 1970-01-19                  0.053546         0.343571
# ...                              ...              ...
# 2025-11-20                 -0.069100         0.241429
# 2025-11-21                 -0.133070         0.241429
# 2025-11-22                 -0.125000         0.241429
# 2025-11-23                 -0.116779         0.241429
# 2025-11-24                 -0.051491         0.241429
#
#             pct_diff_rolling_14_prcp
# DATE
# 1970-01-15                  0.869018
# 1970-01-16                  1.372385
# 1970-01-17                 -1.000000
# 1970-01-18                 -1.000000
# 1970-01-19                 -0.912682
# ...                              ...
# 2025-11-20                 -0.047337
# 2025-11-21                 -1.000000
# 2025-11-22                 -1.000000
# 2025-11-23                 -1.000000
# 2025-11-24                 -1.000000
#
# [20403 rows x 18 columns]

# %%
def expand_mean(df):
  return df.expanding(1).mean()

for col in ["tmax", "tmin", "prcp"]:
  weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
  weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                                        name  prcp  \
# DATE
# 1970-01-15  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.53
# 1970-01-16  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.81
# 1970-01-17  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-18  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 1970-01-19  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.03
# ...                 ...                                         ...   ...
# 2025-11-20  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.23
# 2025-11-21  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-22  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-23  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
# 2025-11-24  USW00023234  SAN FRANCISCO INTERNATIONAL AIRPORT, CA US  0.00
#
#             tmax  tmin  target  rolling_3_tmax  pct_diff_rolling_3_tmax  \
# DATE
# 1970-01-15  59.0  51.0    64.0       60.333333                -0.022099
# 1970-01-16  64.0  55.0    60.0       61.333333                 0.043478
# 1970-01-17  60.0  53.0    60.0       61.000000                -0.016393
# 1970-01-18  60.0  51.0    62.0       61.333333                -0.021739
# 1970-01-19  62.0  52.0    62.0       60.666667                 0.021978
# ...          ...   ...     ...             ...                      ...
# 2025-11-20  60.0  51.0    64.0       60.000000                 0.000000
# 2025-11-21  64.0  47.0    65.0       61.000000                 0.049180
# 2025-11-22  65.0  47.0    58.0       63.000000                 0.031746
# 2025-11-23  58.0  47.0    62.0       62.333333                -0.069519
# 2025-11-24  62.0  50.0    62.0       61.666667                 0.005405
#
#             rolling_3_tmin  pct_diff_rolling_3_tmin  ...  rolling_14_tmin  \
# DATE                                                 ...
# 1970-01-15       52.333333                -0.025478  ...        44.785714
# 1970-01-16       52.666667                 0.044304  ...        45.857143
# 1970-01-17       53.000000                 0.000000  ...        47.142857
# 1970-01-18       53.000000                -0.037736  ...        48.071429
# 1970-01-19       52.000000                 0.000000  ...        49.357143
# ...                    ...                      ...  ...              ...
# 2025-11-20       51.333333                -0.006494  ...        54.785714
# 2025-11-21       50.000000                -0.060000  ...        54.214286
# 2025-11-22       48.333333                -0.027586  ...        53.714286
# 2025-11-23       47.000000                 0.000000  ...        53.214286
# 2025-11-24       48.000000                 0.041667  ...        52.714286
#
#             pct_diff_rolling_14_tmin  rolling_14_prcp  \
# DATE
# 1970-01-15                  0.138756         0.283571
# 1970-01-16                  0.199377         0.341429
# 1970-01-17                  0.124242         0.341429
# 1970-01-18                  0.060921         0.341429
# 1970-01-19                  0.053546         0.343571
# ...                              ...              ...
# 2025-11-20                 -0.069100         0.241429
# 2025-11-21                 -0.133070         0.241429
# 2025-11-22                 -0.125000         0.241429
# 2025-11-23                 -0.116779         0.241429
# 2025-11-24                 -0.051491         0.241429
#
#             pct_diff_rolling_14_prcp  month_avg_tmax  day_avg_tmax  \
# DATE
# 1970-01-15                  0.869018       59.000000     59.000000
# 1970-01-16                  1.372385       61.500000     64.000000
# 1970-01-17                 -1.000000       61.000000     60.000000
# 1970-01-18                 -1.000000       60.750000     60.000000
# 1970-01-19                 -0.912682       61.000000     62.000000
# ...                              ...             ...           ...
# 2025-11-20                 -0.047337       63.173054     61.375000
# 2025-11-21                 -1.000000       63.173549     60.839286
# 2025-11-22                 -1.000000       63.174641     60.821429
# 2025-11-23                 -1.000000       63.171548     61.017857
# 2025-11-24                 -1.000000       63.170848     61.321429
#
#             month_avg_tmin  day_avg_tmin  month_avg_prcp  day_avg_prcp
# DATE
# 1970-01-15       51.000000     51.000000        0.530000      0.530000
# 1970-01-16       53.000000     55.000000        0.670000      0.810000
# 1970-01-17       53.000000     53.000000        0.446667      0.000000
# 1970-01-18       52.500000     51.000000        0.335000      0.000000
# 1970-01-19       52.400000     52.000000        0.274000      0.030000
# ...                    ...           ...             ...           ...
# 2025-11-20       48.391617     47.750000        0.079042      0.077857
# 2025-11-21       48.390784     47.321429        0.078995      0.087857
# 2025-11-22       48.389952     47.178571        0.078947      0.069643
# 2025-11-23       48.389121     47.392857        0.078900      0.082679
# 2025-11-24       48.390084     46.410714        0.078853      0.116429
#
# [20403 rows x 24 columns]

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictors
# Out:
# Index(['prcp', 'tmax', 'tmin', 'rolling_3_tmax', 'pct_diff_rolling_3_tmax',
#        'rolling_3_tmin', 'pct_diff_rolling_3_tmin', 'rolling_3_prcp',
#        'pct_diff_rolling_3_prcp', 'rolling_14_tmax',
#        'pct_diff_rolling_14_tmax', 'rolling_14_tmin',
#        'pct_diff_rolling_14_tmin', 'rolling_14_prcp',
#        'pct_diff_rolling_14_prcp', 'month_avg_tmax', 'day_avg_tmax',
#        'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp', 'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather, rr, predictors)

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 3.442326466004778

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2009-05-15    89.0   65.749244  23.250756
# 1988-07-16   105.0   81.766623  23.233377
# 1995-07-29    93.0   70.089472  22.910528
# 2017-06-17    97.0   74.611191  22.388809
# 2001-05-29    95.0   72.679123  22.320877
# ...            ...         ...        ...
# 2021-08-19    73.0   72.998211   0.001789
# 2024-08-02    70.0   69.998479   0.001521
# 2019-02-08    55.0   55.000233   0.000233
# 2011-11-11    60.0   59.999771   0.000229
# 1991-11-18    63.0   63.000030   0.000030
#
# [16753 rows x 3 columns]

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>
